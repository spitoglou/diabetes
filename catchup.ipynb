# %%
from load_model_and_predict import retrieve_data
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from load_model_and_predict import retrieve_data
#
# ImportError: cannot import name 'retrieve_data' from 'load_model_and_predict' (c:\code\python\diabetes\load_model_and_predict.py)
